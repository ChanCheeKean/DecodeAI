# %% [markdown]
# Loss Functions — Deep Understanding
#
# - Cross-entropy loss: derivation from MLE, numerical stability (log-sum-exp trick)
# - Binary cross-entropy vs categorical cross-entropy
# - Focal loss: handling class imbalance
# - Contrastive loss, triplet loss, InfoNCE loss
# - CTC loss (speech/OCR)
# - Label smoothing: why and how
# Knowledge distillation loss (KD, DKD)
